-- %%
%python
spark.sql("use catalog mvp1")
spark.sql("use schema gold")

-- %%
drop table if exists netflix_customer_churn

-- %%
create table mvp1.gold.netflix_customer_churn as
select*
from mvp1.silver.netflix_customer_churn;
